# %%
# regular imports
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %matplotlib inline

# %%
# display related imports
from IPython.display import display, Image, clear_output, HTML, IFrame

# Widgets
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# to save dataframe as an image
import dataframe_image as dfi

# hide warnings
import warnings
warnings.filterwarnings('ignore')

# Forest
from sklearn.tree import DecisionTreeClassifier

# %%
# Functions

def percent_good(df_, col):
    print('_' * 100) # printing header to seperate the column info
    print('- ' * 20 , col, ' -' * 20)
    # Column Header for Data that follows in the for loop
    print('{:30s}  {:>8s}  {:>8s}  {:>8s}  {:>14s}  {:>8s}'.format('Category', 'Good %', 'Bad %', 'Col %', 'Tot Count', 'Int %'))

    for item_ in df_[col].unique():                               # Item is the unique category item from the column (col)
        tot_ = df_[col].count()                                   # total loans with data for this column
        t_ = df_[df[col]==item_][col].count()                     # Count of loans matching the category for this column
        c_ = df_[(df_[col]==item_) & (df_['good'])][col].count()  # Count of Good Loans 
        b_ = t_ - c_                                              # Count of bad loans (total - good)

        print('{:30s}  {:8.1%}  {:8.1%}  {:8.1%}  {:14,.0f}  {:8.1%}'
              .format(str(item_), c_/t_, b_/t_, t_/tot_, t_, 
                      df_[df[col]==item_]['int_rate'].mean()/100))


def mort_acc_bin(df_):
    '''Changes mort_acc to 0 for none and 1 for true'''
    df_['mort_acc'] = [0 if x== 0.0 else 1 for x in df_['mort_acc']]
    df_['mort_acc'] = df_['mort_acc'].astype('category')
    return df_


def m_bin(item):                                                  # Used to bin larger cat data into smaller amounts of bins
    if item == 0.0:
        return 0
    elif item < 5.0:
        return 1
    elif item < 10:
        return 2
    else:
        return 3
    
def to_true_false(df_, col, item=0):
    df_[col] = [0 if x == item else 1 for x in df_[col]]
    return df_

# %%
df = pd.read_pickle('data/df_accep.pkl')

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  int_rate  installment grade  \
# 0     3600.0       3600.0           3600.0     13.99       123.03     C
# 1    24700.0      24700.0          24700.0     11.99       820.28     C
# 2    20000.0      20000.0          20000.0     10.78       432.66     B
# 3    35000.0      35000.0          35000.0     14.85       829.90     C
# 4    10400.0      10400.0          10400.0     22.45       289.91     F
#
#   sub_grade                    emp_title emp_length home_ownership  ...  \
# 0        C4                      leadman  10+ years       MORTGAGE  ...
# 1        C1                     Engineer  10+ years       MORTGAGE  ...
# 2        B4                 truck driver  10+ years       MORTGAGE  ...
# 3        C5  Information Systems Officer  10+ years       MORTGAGE  ...
# 4        F1          Contract Specialist    3 years       MORTGAGE  ...
#
#    settlement_percentage settlement_term issue_year issue_month fico term_60  \
# 0                    NaN             NaN       2015          12    3       0
# 1                    NaN             NaN       2015          12    3       0
# 2                    NaN             NaN       2015          12    3       1
# 3                    NaN             NaN       2015          12    4       1
# 4                    NaN             NaN       2015          12    3       1
#
#   years_since_earliest_credit last_pay_d months_of_pay loss_amnt
# 0                          12 2019-01-01            36       0.0
# 1                          16 2016-06-01             5       0.0
# 2                          15 2017-06-01            17       0.0
# 3                           7 2019-02-01            37       0.0
# 4                          17 2016-07-01             5       0.0
#
# [5 rows x 152 columns]

# %% [markdown]
# # The Good Field!
# The good field has only one purpose in life, to show the good loans!
# What are good loans? Loans that pay off, or are current in at this time!
#
# True for Good, False for BAD!
#
# This is the field that all other fields will be judged by!
# That's right, we are a bit judgy here...

# %%
df['good']=[True if x in ['Current', 'Fully Paid'] else False for x in df['loan_status']]

# %%
# fixing some fields here, more to be added shortly
df = mort_acc_bin(df)
df['earliest_credit_10_more'] = [0 if x<10 else 1 for x in df['years_since_earliest_credit']]

# %%
# test of above and the percent_good function above
percent_good(df, 'mort_acc')
# Out:
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  mort_acc  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# 1                                  87.7%     12.3%     58.9%       1,331,062     12.7%
# 0                                  84.9%     15.1%     41.1%         929,606     13.6%

# %%
# Fields that are dropped, more to come!
to_drop = [
    'pymnt_plan',
    'url',
    'desc',
    'emp_title',
    'pymnt_plan',
    'title',
    'next_pymnt_d',
    'deferral_term',
    'years_since_earliest_credit',
    'debt_settlement_flag', 
    'orig_projected_additional_accrued_interest', 
    'payment_plan_start_date', 
    'sec_app_fico_range_high'
]
hard_ = [col for col in df if col.startswith('hard')]
settle_ = [col for col in df if col.startswith('settle')]
df.drop(to_drop, axis=1, inplace=True)
df.drop(hard_, axis=1, inplace=True)
df.drop(settle_, axis=1, inplace=True)

# %%
# save data for filter viewing in another notebook
df.to_csv('data/df_for_filter.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-4b369597d1e7> in <module>
#       1 # save data for filter viewing in another notebook
# ----> 2 df.to_csv('data/df_for_filter.csv')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     204             )
#     205
# --> 206             self._save()
#     207
#     208         finally:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in _save(self)
#     326                 break
#     327
# --> 328             self._save_chunk(start_i, end_i)
#     329
#     330     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     339         for i in range(len(blocks)):
#     340             b = blocks[i]
# --> 341             d = b.to_native_types(
#     342                 na_rep=self.na_rep,
#     343                 float_format=self.float_format,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in to_native_types(self, na_rep, date_format, **kwargs)
#    2124         dta = self.array_values()
#    2125
# -> 2126         result = dta._format_native_types(
#    2127             na_rep=na_rep, date_format=date_format, **kwargs
#    2128         )
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in _format_native_types(self, na_rep, date_format, **kwargs)
#     607         fmt = _get_format_datetime64_from_values(self, date_format)
#     608
# --> 609         return tslib.format_array_from_datetime(
#     610             self.asi8.ravel(), tz=self.tz, format=fmt, na_rep=na_rep
#     611         ).reshape(self.shape)
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.format_array_from_datetime()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# KeyboardInterrupt:

# %%
df = to_true_false(df, 'tax_liens')
df = to_true_false(df, 'disbursement_method', 'cash')
df = to_true_false(df, 'emp_length', '10+ years')
df.rename(columns={'disbursement_method': 'disb_direct', 'emp_length': 'emp_len_under_10'}, inplace=True)
#df['delinq_2yrs'] = [m_bin(x) for x in df['delinq_2yrs']]

# %%
col_ = ['inq_last_6mths', 
       'open_acc',
        'collections_12_mths_ex_med',
        'open_acc_6m',
        'collections_12_mths_ex_med',
        'delinq_2yrs',
        'pub_rec',
        'acc_now_delinq',
        'open_il_12m',
        'open_il_24m',
        'num_tl_90g_dpd_24m',
        'num_tl_op_past_12m'
        
       ]

for col in col_:
    df[col] = [m_bin(x) for x in df[col]]
df['delinq_2yrs'].unique
# Out:
# <bound method Series.unique of 0          0
# 1          1
# 2          0
# 3          0
# 4          1
#           ..
# 2260694    0
# 2260695    0
# 2260696    2
# 2260697    0
# 2260698    0
# Name: delinq_2yrs, Length: 2260668, dtype: int64>

# %%
# months since

m = 36 # using 36 as cutoff - might change to 50 or use this as a controlled variable later
for col_ in df.columns:
    if col_.startswith('mths'):
        df[col_] = [0 if x < m else 1 for x in df[col_]]

# %%
percent_good(df, 'emp_len_under_10')
# Out:
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  emp_len_under_10  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# 0                                  87.5%     12.5%     33.1%         748,005     13.0%
# 1                                  86.1%     13.9%     66.9%       1,512,663     13.1%

# %%
# This is the magic! This little bit of lovely code will print all the columns that it can, 
# based on unique values in the columns with percent GOOD, BAD, Percent of Column, 
# Number of Loans in, Category and Interest Rate
for col in df.columns:
    if len(df[col].unique()) < 55:
        percent_good(df, col)
    else:
        if col != 'int_rate':
            print('-' * 100)
            print('- '* 20 , col, ' -' * 20)
            print('Unique Items = ', len(df[col].unique()), type(col))
            try:
                df[col]=pd.qcut(df[col], q=4)
                percent_good(df, col)
            except:
                print('Column : ', col, " can't be converted")
# Out:
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  loan_amnt  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  1572 <class 'str'>
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  loan_amnt  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# (499.999, 5000.0]                  89.2%     10.8%     13.2%         299,371     12.8%
# (23025.0, 30000.0]                 85.4%     14.6%     12.4%         281,125     13.8%
# (19350.0, 23025.0]                 85.3%     14.7%     10.0%         225,997     13.5%
# (30000.0, 40000.0]                 86.1%     13.9%      7.6%         170,833     13.9%
# (10325.0, 12900.0]                 85.6%     14.4%     10.0%         225,965     13.3%
# (9450.0, 10325.0]                  87.9%     12.1%     10.0%         225,629     12.4%
# (7000.0, 9450.0]                   87.2%     12.8%      8.6%         194,697     12.2%
# (15000.0, 19350.0]                 84.1%     15.9%      9.8%         222,420     13.7%
# (5000.0, 7000.0]                   88.5%     11.5%      8.2%         184,718     12.1%
# (12900.0, 15000.0]                 86.2%     13.8%     10.2%         229,913     13.0%
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  funded_amnt  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  1572 <class 'str'>
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  funded_amnt  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# (499.999, 5000.0]                  89.2%     10.8%     13.2%         299,479     12.8%
# (23000.0, 30000.0]                 85.4%     14.6%     12.4%         280,885     13.8%
# (19300.0, 23000.0]                 85.2%     14.8%     10.0%         226,273     13.5%
# (30000.0, 40000.0]                 86.1%     13.9%      7.5%         170,675     13.9%
# (10300.0, 12875.0]                 85.6%     14.4%     10.0%         226,128     13.3%
# (9425.0, 10300.0]                  87.9%     12.1%     10.0%         226,196     12.4%
# (7000.0, 9425.0]                   87.2%     12.8%      8.6%         193,883     12.2%
# (15000.0, 19300.0]                 84.1%     15.9%      9.8%         222,009     13.7%
# (5000.0, 7000.0]                   88.5%     11.5%      8.2%         184,872     12.1%
# (12875.0, 15000.0]                 86.2%     13.8%     10.2%         230,268     13.0%
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  funded_amnt_inv  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  10057 <class 'str'>
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  funded_amnt_inv  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# (-0.001, 5000.0]                   89.1%     10.9%     13.3%         301,229     12.8%
# (23000.0, 30000.0]                 85.4%     14.6%     12.4%         280,489     13.8%
# (19200.0, 23000.0]                 85.2%     14.8%     10.0%         227,060     13.5%
# (30000.0, 40000.0]                 86.1%     13.9%      7.5%         170,595     13.9%
# (10200.0, 12800.0]                 85.6%     14.4%     10.0%         226,656     13.3%
# (9325.0, 10200.0]                  87.9%     12.1%     10.0%         225,893     12.4%
# (7000.0, 9325.0]                   87.3%     12.7%      8.5%         192,381     12.2%
# (15000.0, 19200.0]                 84.1%     15.9%      9.8%         220,786     13.7%
# (5000.0, 7000.0]                   88.5%     11.5%      8.2%         184,944     12.1%
# (12800.0, 15000.0]                 86.2%     13.8%     10.2%         230,635     13.0%
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  installment  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  93301 <class 'str'>
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  installment  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# (4.928999999999999, 159.4]         90.2%      9.8%     10.0%         226,685     12.3%
# (652.58, 826.43]                   85.6%     14.4%     10.0%         226,080     13.7%
# (377.99, 459.47]                   85.2%     14.8%     10.0%         226,088     13.6%
# (826.43, 1719.83]                  85.1%     14.9%     10.0%         226,053     14.4%
# (277.18, 327.34]                   87.3%     12.7%     10.1%         229,008     12.3%
# (536.81, 652.58]                   85.3%     14.7%     10.0%         226,006     13.5%
# (221.46, 277.18]                   87.3%     12.7%     10.0%         226,387     12.5%
# (459.47, 536.81]                   85.4%     14.6%     10.0%         226,078     13.1%
# (327.34, 377.99]                   85.5%     14.5%      9.9%         222,828     13.5%
# (159.4, 221.46]                    88.7%     11.3%     10.0%         225,455     12.1%
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  grade  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# C                                  85.0%     15.0%     28.8%         650,053     14.1%
# B                                  90.9%      9.1%     29.4%         663,557     10.7%
# F                                  62.7%     37.3%      1.8%          41,800     25.5%
# A                                  96.2%      3.8%     19.2%         433,027      7.1%
# E                                  70.8%     29.2%      6.0%         135,639     21.8%
# D                                  78.8%     21.2%     14.4%         324,424     18.1%
# G                                  58.8%     41.2%      0.5%          12,168     28.1%
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  sub_grade  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# C4                                 83.3%     16.7%      5.6%         127,115     14.9%
# C1                                 87.3%     12.7%      6.5%         145,903     12.8%
# B4                                 89.9%     10.1%      6.2%         139,793     11.4%
# C5                                 82.6%     17.4%      5.2%         116,726     15.8%
# F1                                 66.1%     33.9%      0.6%          13,413     24.5%
# C3                                 85.1%     14.9%      5.7%         129,193     14.1%
# B2                                 92.4%      7.6%      5.6%         126,621     10.0%
# B1                                 93.1%      6.9%      5.5%         125,341      9.1%
# A2                                 97.0%      3.0%      3.1%          69,562      6.6%
# B5                                 88.7%     11.3%      6.2%         140,288     12.0%
# C2                                 85.8%     14.2%      5.8%         131,116     13.5%
# E2                                 70.9%     29.1%      1.3%          29,924     21.0%
# A4                                 95.6%      4.4%      4.2%          95,874      7.6%
# E3                                 70.5%     29.5%      1.2%          26,708     21.9%
# A1                                 98.1%      1.9%      3.8%          86,790      5.6%
# D4                                 77.3%     22.7%      2.5%          56,896     19.1%
# F3                                 62.1%     37.9%      0.3%           7,791     25.8%
# D1                                 80.4%     19.6%      3.6%          81,787     16.7%
# B3                                 90.9%      9.1%      5.8%         131,514     10.7%
# E4                                 69.6%     30.4%      1.0%          22,763     22.8%
# D3                                 78.9%     21.1%      2.9%          64,819     18.4%
# D2                                 79.5%     20.5%      3.2%          72,899     17.6%
# D5                                 76.4%     23.6%      2.1%          48,023     20.1%
# A5                                 94.3%      5.7%      4.8%         107,617      8.2%
# F2                                 62.7%     37.3%      0.4%           9,305     25.0%
# E1                                 72.4%     27.6%      1.5%          33,573     20.3%
# F5                                 59.0%     41.0%      0.2%           5,167     27.1%
# E5                                 70.1%     29.9%      1.0%          22,671     24.1%
# A3                                 96.6%      3.4%      3.2%          73,184      7.1%
# G2                                 57.8%     42.2%      0.1%           2,688     27.7%
# G1                                 62.0%     38.0%      0.2%           4,106     27.9%
# G3                                 56.9%     43.1%      0.1%           2,094     28.1%
# G4                                 57.0%     43.0%      0.1%           1,712     28.6%
# F4                                 59.2%     40.8%      0.3%           6,124     26.3%
# G5                                 57.0%     43.0%      0.1%           1,568     28.8%
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  emp_len_under_10  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# 0                                  87.5%     12.5%     33.1%         748,005     13.0%
# 1                                  86.1%     13.9%     66.9%       1,512,663     13.1%
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  home_ownership  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# MORTGAGE                           88.3%     11.7%     49.2%       1,111,450     12.7%
# RENT                               84.4%     15.6%     39.6%         894,929     13.5%
# OWN                                86.5%     13.5%     11.2%         253,057     13.1%
# ANY                                91.9%      8.1%      0.0%             996     12.9%
# NONE                               85.2%     14.8%      0.0%              54     14.3%
# OTHER                              79.1%     20.9%      0.0%             182     13.5%
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  annual_inc  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  89369 <class 'str'>
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  annual_inc  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# (50000.0, 58000.0]                 85.6%     14.4%      8.9%         200,860     13.4%
# (58000.0, 65000.0]                 85.8%     14.2%     10.4%         234,992     13.2%
# (100000.0, 130000.0]               89.0%     11.0%     10.3%         231,720     12.4%
# (-0.001, 34000.0]                  84.1%     15.9%     10.2%         229,776     14.1%
# (130000.0, 110000000.0]            90.3%      9.7%      9.5%         215,433     12.0%
# (75000.0, 85000.0]                 87.1%     12.9%      8.6%         193,657     12.9%
# (34000.0, 42000.0]                 84.5%     15.5%     10.1%         228,031     13.7%
# (85000.0, 100000.0]                88.0%     12.0%     10.0%         226,518     12.7%
# (65000.0, 75000.0]                 86.6%     13.4%     10.7%         242,827     13.0%
# (42000.0, 50000.0]                 85.0%     15.0%     11.4%         256,850     13.5%
# nan                                 nan%      nan%      0.0%               0      nan%
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  verification_status  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# Not Verified                       90.7%      9.3%     32.9%         744,806     11.6%
# Source Verified                    86.0%     14.0%     39.2%         886,231     13.2%
# Verified                           82.4%     17.6%     27.9%         629,631     14.7%
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  issue_d  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  139 <class 'str'>
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  issue_d  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# (2015-07-01, 2016-01-01]           81.8%     18.2%     10.1%         227,397     12.4%
# (2014-11-01, 2015-07-01]           81.3%     18.7%     10.5%         236,371     12.8%
# (2018-02-01, 2018-07-01]           94.6%      5.4%      9.4%         212,632     12.6%
# (2017-08-01, 2018-02-01]           90.9%      9.1%     10.1%         227,454     12.9%
# (2017-02-01, 2017-08-01]           87.7%     12.3%     10.0%         225,620     13.3%
# (2016-01-01, 2016-07-01]           81.8%     18.2%     10.4%         234,071     12.7%
# (2018-07-01, 2018-12-01]           98.1%      1.9%      9.4%         213,517     12.9%
# (2013-12-01, 2014-11-01]           82.2%     17.8%     10.0%         225,322     13.8%
# (2007-05-31 23:59:59.999999999, 2013-12-01]     84.4%     15.6%     10.2%         230,716     13.9%
# (2016-07-01, 2017-02-01]           84.4%     15.6%     10.1%         227,568     13.6%
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -
- - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# 0                                  87.1%     12.9%     84.2%       1,902,758     13.0%
# 1                                  83.8%     16.2%     15.7%         353,983     13.8%
# 2                                  83.1%     16.9%      0.2%           3,589     13.8%
# 3                                  82.5%     17.5%      0.0%             338     13.2%
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  revol_bal  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  102251 <class 'str'>
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  revol_bal  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# (-0.001, 2934.0]                   86.7%     13.3%     10.0%         226,134     13.2%
# (17813.0, 23316.0]                 86.4%     13.6%     10.0%         226,060     13.2%
# (6928.0, 8993.0]                   85.9%     14.1%     10.0%         226,087     13.1%
# (33527.0, 2904836.0]               89.0%     11.0%     10.0%         226,061     12.7%
# (8993.0, 11324.0]                  86.0%     14.0%     10.0%         226,065     13.1%
# (11324.0, 14130.0]                 86.0%     14.0%     10.0%         226,057     13.1%
# (23316.0, 33527.0]                 87.2%     12.8%     10.0%         226,061     13.2%
# (14130.0, 17813.0]                 86.0%     14.0%     10.0%         226,024     13.2%
# (4991.0, 6928.0]                   86.1%     13.9%     10.0%         226,077     13.1%
# (2934.0, 4991.0]                   86.4%     13.6%     10.0%         226,042     13.2%
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  revol_util  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  1431 <class 'str'>
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  revol_util  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# (27.2, 35.5]                       88.2%     11.8%     10.0%         226,770     12.1%
# (16.7, 27.2]                       89.6%     10.4%     10.0%         226,782     11.5%
# (50.3, 57.6]                       85.7%     14.3%     10.0%         226,129     13.4%
# (-0.001, 16.7]                     90.6%      9.4%     10.0%         226,220     10.9%
# (57.6, 65.2]                       85.1%     14.9%      9.9%         224,246     13.8%
# (65.2, 73.8]                       84.7%     15.3%     10.0%         226,358     14.1%
# (84.2, 892.3]                      83.7%     16.3%      9.9%         224,382     15.1%
# (35.5, 43.0]                       87.2%     12.8%     10.0%         225,801     12.6%
# (43.0, 50.3]                       86.4%     13.6%     10.0%         226,229     13.0%
# (73.8, 84.2]                       84.3%     15.7%     10.0%         225,949     14.5%
# nan                                 nan%      nan%      0.0%               0      nan%
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  total_acc  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  153 <class 'str'>
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  total_acc  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# (10.0, 14.0]                       86.8%     13.2%     11.9%         269,744     13.4%
# (33.0, 40.0]                       86.2%     13.8%      9.9%         224,648     12.8%
# (17.0, 20.0]                       86.7%     13.3%     10.9%         246,513     13.1%
# (14.0, 17.0]                       86.7%     13.3%     10.5%         238,179     13.2%
# (0.999, 10.0]                      87.4%     12.6%     10.0%         226,485     13.7%
# (25.0, 29.0]                       86.5%     13.5%     11.3%         254,636     12.9%
# (22.0, 25.0]                       86.5%     13.5%     10.0%         225,497     12.9%
# (29.0, 33.0]                       86.4%     13.6%      8.8%         198,608     12.8%
# (20.0, 22.0]                       86.6%     13.4%      7.1%         160,608     13.0%
# (40.0, 176.0]                      85.7%     14.3%      9.5%         215,721     13.0%
# nan                                 nan%      nan%      0.0%               0      nan%
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  initial_list_status  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# w                                  87.9%     12.1%     67.9%       1,535,467     12.7%
# f                                  83.7%     16.3%     32.1%         725,201     13.9%
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  out_prncp  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  356141 <class 'str'>
# Column :  out_prncp  can't be converted
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  out_prncp_inv  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  368481 <class 'str'>
# Column :  out_prncp_inv  can't be converted
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  total_pymnt  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  1633857 <class 'str'>
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  total_pymnt  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
#

# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  total_rec_late_fee  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  18375 <class 'str'>
# Column :  total_rec_late_fee  can't be converted
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  recoveries  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  132777 <class 'str'>
# Column :  recoveries  can't be converted
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  collection_recovery_fee  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  146222 <class 'str'>
# Column :  collection_recovery_fee  can't be converted
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  last_pymnt_d  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  137 <class 'str'>
# Column :  last_pymnt_d  can't be converted
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  last_pymnt_amnt  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  704467 <class 'str'>
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  last_pymnt_amnt  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# (-0.001, 167.97]                   82.6%     17.4%     10.0%         226,336     12.5%
# (842.99, 2032.128]                 85.7%     14.3%     10.0%         226,063     13.4%
# (11550.576, 42192.05]              99.9%      0.1%     10.0%         226,067     14.4%
# (600.57, 842.99]                   80.4%     19.6%     10.0%         226,063     13.4%
# (5711.986, 11550.576]              99.9%      0.1%     10.0%         226,067     12.6%
# (2032.128, 5711.986]               99.6%      0.4%     10.0%         226,067     12.0%
# (458.92, 600.57]                   77.9%     22.1%     10.0%         226,065     13.7%
# (344.17, 458.92]                   78.2%     21.8%     10.0%         225,932     13.7%
# (167.97, 266.88]                   81.5%     18.5%     10.0%         225,848     12.4%
# (266.88, 344.17]                   80.0%     20.0%     10.0%         226,160     12.7%
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  last_credit_pull_d  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  142 <class 'str'>
# Column :  last_credit_pull_d  can't be converted
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  last_fico_range_high  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  72 <class 'str'>
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  last_fico_range_high  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# (-0.001, 574.0]                    26.5%     73.5%     10.4%         234,408     15.6%
# (684.0, 699.0]                     98.1%      1.9%     10.8%         243,211     13.5%
# (699.0, 714.0]                     98.7%      1.3%     10.8%         244,087     12.9%
# (669.0, 684.0]                     96.9%      3.1%      9.4%         212,679     14.0%
# (744.0, 774.0]                     99.5%      0.5%     10.3%         231,830     10.9%
# (639.0, 669.0]                     91.5%      8.5%     11.2%         253,495     14.5%
# (714.0, 729.0]                     99.0%      1.0%      9.7%         218,883     12.2%
# (574.0, 639.0]                     63.0%     37.0%     10.7%         241,899     15.1%
# (774.0, 850.0]                     99.5%      0.5%      9.1%         205,267      9.7%
# (729.0, 744.0]                     99.3%      0.7%      7.7%         174,909     11.6%
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  last_fico_range_low  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  71 <class 'str'>
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  last_fico_range_low  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# (-0.001, 570.0]                    26.5%     73.5%     10.4%         234,408     15.6%
# (680.0, 695.0]                     98.1%      1.9%     10.8%         243,211     13.5%
# (695.0, 710.0]                     98.7%      1.3%     10.8%         244,087     12.9%
# (665.0, 680.0]                     96.9%      3.1%      9.4%         212,679     14.0%
# (740.0, 770.0]                     99.5%      0.5%     10.3%         231,830     10.9%
# (635.0, 665.0]                     91.5%      8.5%     11.2%         253,495     14.5%
# (710.0, 725.0]                     99.0%      1.0%      9.7%         218,883     12.2%
# (570.0, 635.0]                     63.0%     37.0%     10.7%         241,899     15.1%
# (770.0, 845.0]                     99.5%      0.5%      9.1%         205,267      9.7%
# (725.0, 740.0]                     99.3%      0.7%      7.7%         174,909     11.6%
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  collections_12_mths_ex_med  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# 0                                  86.6%     13.4%     98.3%       2,223,085     13.1%
# 1                                  83.6%     16.4%      1.7%          37,583     13.8%
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  mths_since_last_major_derog  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# 0                                  84.3%     15.7%      9.5%         214,626     14.0%
# 1                                  86.8%     13.2%     90.5%       2,046,042     13.0%
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  policy_code  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# 1.0                                86.6%     13.4%    100.0%       2,260,668     13.1%
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -
9%
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  sec_app_mths_since_last_major_derog  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  141 <class 'str'>
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  sec_app_mths_since_last_major_derog  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# nan                                 nan%      nan%      0.0%               0      nan%
# (36.0, 43.0]                       91.4%      8.6%      9.1%           3,281     14.4%
# (20.0, 28.0]                       89.2%     10.8%     10.1%           3,628     14.7%
# (61.0, 70.0]                       92.2%      7.8%      9.3%           3,358     13.9%
# (28.0, 36.0]                       90.7%      9.3%     10.2%           3,673     14.5%
# (43.0, 51.0]                       92.1%      7.9%     10.0%           3,590     14.3%
# (5.0, 13.0]                        88.0%     12.0%     11.1%           3,999     14.9%
# (13.0, 20.0]                       89.4%     10.6%      9.3%           3,354     14.8%
# (-0.001, 5.0]                      85.7%     14.3%     10.2%           3,681     15.3%
# (70.0, 185.0]                      93.0%      7.0%      9.8%           3,509     13.7%
# (51.0, 61.0]                       92.0%      8.0%     10.8%           3,869     14.2%
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  disb_direct  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# 1                                  86.6%     13.4%    100.0%       2,260,668     13.1%
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  debt_settlement_flag_date  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  84 <class 'str'>
# Column :  debt_settlement_flag_date  can't be converted
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  issue_year  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# 2015                               81.5%     18.5%     18.6%         421,095     12.6%
# 2018                               95.8%      4.2%     21.9%         495,242     12.7%
# 2017                               88.4%     11.6%     19.6%         443,579     13.2%
# 2016                               82.6%     17.4%     19.2%         434,407     13.0%
# 2014                               82.3%     17.7%     10.4%         235,629     13.8%
# 2011                               84.8%     15.2%      1.0%          21,721     12.2%
# 2010                               86.0%     14.0%      0.6%          12,537     12.0%
# 2009                               86.3%     13.7%      0.2%           5,281     12.4%
# 2008                               79.3%     20.7%      0.1%           2,393     12.1%
# 2007                               73.8%     26.2%      0.0%             603     11.8%
# 2013                               84.4%     15.6%      6.0%         134,814     14.5%
# 2012                               83.8%     16.2%      2.4%          53,367     13.6%
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  issue_month  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# 12                                 87.9%     12.1%      8.6%         194,892     13.0%
# 11                                 87.9%     12.1%      9.2%         207,032     13.0%
# 10                                 87.3%     12.7%     10.1%         229,215     13.1%
# 9                                  87.5%     12.5%      7.5%         169,077     13.4%
# 8                                  87.2%     12.8%      9.0%         202,454     13.3%
# 7                                  86.0%     14.0%      9.4%         212,699     13.4%
# 6                                  86.5%     13.5%      7.8%         176,513     13.0%
# 5                                  86.2%     13.8%      8.0%         180,324     13.0%
# 4                                  85.6%     14.4%      7.9%         179,257     13.0%
# 3                                  85.3%     14.7%      8.6%         194,046     12.9%
# 2                                  85.5%     14.5%      6.7%         151,786     13.0%
# 1                                  85.4%     14.6%      7.2%         163,373     13.0%
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  fico  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# 3                                  86.5%     13.5%     71.3%       1,610,768     13.3%
# 4                                  93.8%      6.2%     11.1%         251,024      9.3%
# 2                                  81.0%     19.0%     16.3%         367,828     15.3%
# 5                                  96.0%      4.0%      1.4%          31,048      7.8%
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  term_60  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# 0                                  88.6%     11.4%     71.2%       1,609,754     11.9%
# 1                                  81.6%     18.4%     28.8%         650,914     15.9%
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  last_pay_d  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  137 <class 'str'>
# Column :  last_pay_d  can't be converted
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  months_of_pay  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  70 <class 'str'>
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  months_of_pay  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# (35.0, 68.0]                       92.5%      7.5%      6.5%         146,229     14.6%
# (3.0, 6.0]                         83.9%     16.1%     10.3%         232,886     13.5%
# (16.0, 20.0]                       84.6%     15.4%      9.9%         224,063     13.0%
# (12.0, 16.0]                       83.6%     16.4%     10.7%         242,438     13.1%
# (9.0, 12.0]                        81.4%     18.6%      9.4%         213,306     13.1%
# (25.0, 31.0]                       87.2%     12.8%      9.8%         221,084     12.7%
# (20.0, 25.0]                       85.0%     15.0%      9.6%         216,758     12.8%
# (6.0, 9.0]                         83.4%     16.6%      9.9%         223,459     13.1%
# (-1.001, 3.0]                      87.1%     12.9%     11.5%         260,488     13.8%
# (31.0, 35.0]                       96.5%      3.5%     12.4%         279,957     11.9%
# ----------------------------------------------------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - -  loss_amnt  - - - - - - - - - - - - - - - - - - - -
# Unique Items =  34331 <class 'str'>
# Column :  loss_amnt  can't be converted
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  good  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# True                              100.0%      0.0%     86.6%       1,957,056     12.7%
# False                               0.0%    100.0%     13.4%         303,612     15.7%
# ____________________________________________________________________________________________________
# - - - - - - - - - - - - - - - - - - - -  earliest_credit_10_more  - - - - - - - - - - - - - - - - - - - -
# Category                          Good %     Bad %     Col %       Tot Count     Int %
# 1                                  86.9%     13.1%     82.8%       1,872,416     12.9%
# 0                                  85.0%     15.0%     17.2%         388,252     13.9%

# %%
# find the loss on the bad
# can we do better than the 86.6%?

# %% [markdown]
# think of the returns as time value of money... you recieve the payments each month (p & i) minus 1% and any late or no payments
# You must reinvest or accept that you recieve the lower amount of interest each month until you do reinvest the money
#
#
# Some strategies (get out of higher risk loans before they start hitting danger zone - what is the penalty to selling? do other investers know this
# and therefore pay a reduced price for this loan?

# %%
# credit usually only uses the low fico not both

# %%
loan_amnts = ['funded_amnt_inv', 'funded_amnt', 'loan_amnt']

# %%
# reduce or do something with

# %%
sec_app_mths_since_last_major_derog, sec_app_open_act_il, sec_app_mort_acc

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 40)

# %%
issue_year_ = 2013
grade_ = ['D', 'E', 'F']
fico_ = 1 # above this
min_int_rate_ = 14.5
emp_length_ = '<1 year'
annual_inc_ = 70000
earliest_credit_10_more_ = 1
loan_amnt_ = 25001
term_60_ = 0
chargeoff_within_12_mths_ = 0
purpose_ = ['credit_card', 'debt_consolidation']
total_acc_ = 25 # less than this amount
installment_ = 800
issue_month_ = [1,3]

# %%
df_filtered = df[(df['issue_year']==issue_year_) & 
   (df['grade'].isin(grade_)) & 
   (df['fico']>fico_) & 
   (df['int_rate']>min_int_rate_) & 
   (df['home_ownership']!='RENT') & 
   (df['emp_length']!= emp_length_) &
   (df['annual_inc'] > annual_inc_) &
   (df['earliest_credit_10_more'] == earliest_credit_10_more_) &
   (df['loan_amnt'] < loan_amnt_) &
   (df['term_60']==term_60_) &
   (df['purpose'].isin(purpose_)) &
   (df['total_acc'] < total_acc_) &
   (df['installment'] < installment_) &
   (df['issue_month'].isin(issue_month_))
  ].iloc[:,[117,116, 13, 118, 15, 9, 5, 6, 7, 8, 0,3,4, 119, 124, 12, 121, 122, 123, 28, 29, 30, 31, 32, 33]].sort_values(['issue_month', 'int_rate'])
print(df_filtered.groupby('good')['loss_amnt'].count())
loss = round(df_filtered[df_filtered['good']!=True]['loss_amnt'].sum(),-1)
loan = round(df_filtered[df_filtered['good']!=True]['loan_amnt'].sum(),-1)
print('Loss amount :', loss)
print('Loan amount :', loan)
print('Loss / Loan :', round(loss/loan, 3))
# total_pymnt_inv loan_amnt
rec = df_filtered['total_pymnt_inv'].sum()
paid_out = df_filtered['loan_amnt'].sum()
gain = rec - paid_out
print('Total rec   :', round(rec, -1))
print('Total paid  :', round(paid_out, -1))
print('Total gain  :', round(gain, -1))
print('Percent     :', round(gain/paid_out * 100, 1))


df_filtered
# Out:
# good
# False    3
# True     9
# Name: loss_amnt, dtype: int64
# Loss amount : 1960.0
# Loan amount : 35100.0
# Loss / Loan : 0.056
# Total rec   : 165600.0
# Total paid  : 148420.0
# Total gain  : 17180.0
# Percent     : 11.6
#          issue_month  issue_year             purpose  fico    dti  annual_inc  \
# 1882504            1        2013  debt_consolidation     3  15.83     78000.0
# 1883125            1        2013  debt_consolidation     2  16.78    116000.0
# 1863642            3        2013  debt_consolidation     2  21.66     75000.0
# 1864136            3        2013  debt_consolidation     3  21.03     73000.0
# 1868199            3        2013  debt_consolidation     3  27.13     77000.0
# 1869520            3        2013  debt_consolidation     2   6.41    105000.0
# 1870914            3        2013  debt_consolidation     3  12.26     74000.0
# 1865075            3        2013         credit_card     2   6.20    112000.0
# 1867839            3        2013  debt_consolidation     3  11.83     72000.0
# 1870803            3        2013  debt_consolidation     2  18.59     89000.0
# 1870951            3        2013         credit_card     2  25.12     74000.0
# 1864223            3        2013  debt_consolidation     2  25.70    110000.0
#
#         grade sub_grade emp_length home_ownership  loan_amnt  int_rate  \
# 1882504     D        D1  10+ years       MORTGAGE     4000.0     17.77
# 1883125     E        E3  10+ years       MORTGAGE    16000.0     21.49
# 1863642     D        D1    6 years            OWN    19500.0     17.77
# 1864136     D        D1  10+ years       MORTGAGE    20000.0     17.77
# 1868199     D        D1  10+ years            OWN    10000.0     17.77
# 1869520     D        D1    3 years       MORTGAGE    21325.0     17.77
# 1870914     D        D1  10+ years            OWN     6000.0     17.77
# 1865075     D        D2   < 1 year       MORTGAGE     9000.0     18.49
# 1867839     D        D2  10+ years       MORTGAGE     7500.0     18.49
# 1870803     D        D2  10+ years       MORTGAGE     9600.0     18.49
# 1870951     D        D3  10+ years       MORTGAGE    18000.0     18.75
# 1864223     D        D5    6 years       MORTGAGE     7500.0     19.72
#
#          installment  term_60  earliest_credit_10_more  loan_status  \
# 1882504       144.15        0                        1   Fully Paid
# 1883125       606.84        0                        1   Fully Paid
# 1863642       702.73        0                        1   Fully Paid
# 1864136       720.75        0                        1   Fully Paid
# 1868199       360.38        0                        1   Fully Paid
# 1869520       768.50        0                        1   Fully Paid
# 1870914       216.23        0                        1   Fully Paid
# 1865075       327.59        0                        1   Fully Paid
# 1867839       273.00        0                        1   Fully Paid
# 1870803       349.43        0                        1  Charged Off
# 1870951       657.54        0                        1  Charged Off
# 1864223       277.66        0                        1  Charged Off
#
#          months_of_pay  loss_amnt   good   total_pymnt  total_pymnt_inv  \
# 1882504             12        0.0   True   4707.775234          4707.78
# 1883125              1        0.0   True  16843.609586         16843.61
# 1863642             15        0.0   True  23144.569781         23144.57
# 1864136              6        0.0   True  21681.204973         21681.20
# 1868199             35        0.0   True  12973.265902         12973.27
# 1869520             21        0.0   True  26640.489962         26515.56
# 1870914             35        0.0   True   7783.937329          7783.94
# 1865075             35        0.0   True  11793.149695         11727.63
# 1867839             22        0.0   True   9529.430000          9529.43
# 1870803             10     4227.0  False   4269.580000          4269.58
# 1870951             26    -2301.0  False  19445.390000         19445.39
# 1864223             22       30.0  False   6978.930000          6978.93
#
#          total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries
# 1882504          4000.00         707.78                 0.0        0.00
# 1883125         16000.00         843.61                 0.0        0.00
# 1863642         19500.00        3644.57                 0.0        0.00
# 1864136         20000.00        1681.20                 0.0        0.00
# 1868199         10000.00        2973.27                 0.0        0.00
# 1869520         21325.00        5315.49                 0.0        0.00
# 1870914          6000.00        1783.94                 0.0        0.00
# 1865075          9000.00        2793.15                 0.0        0.00
# 1867839          7500.00        2029.43                 0.0        0.00
# 1870803          1692.40        1461.54                 0.0     1115.64
# 1870951         13085.96        5316.58                 0.0     1042.85
# 1864223          4270.34        2110.23                 0.0      598.36

# %%
for i,v in enumerate(df.columns):
    print(i,"'"+v+"'")
# Out:
# 0 'loan_amnt'
# 1 'funded_amnt'
# 2 'funded_amnt_inv'
# 3 'int_rate'
# 4 'installment'
# 5 'grade'
# 6 'sub_grade'
# 7 'emp_length'
# 8 'home_ownership'
# 9 'annual_inc'
# 10 'verification_status'
# 11 'issue_d'
# 12 'loan_status'
# 13 'purpose'
# 14 'addr_state'
# 15 'dti'
# 16 'delinq_2yrs'
# 17 'inq_last_6mths'
# 18 'mths_since_last_delinq'
# 19 'mths_since_last_record'
# 20 'open_acc'
# 21 'pub_rec'
# 22 'revol_bal'
# 23 'revol_util'
# 24 'total_acc'
# 25 'initial_list_status'
# 26 'out_prncp'
# 27 'out_prncp_inv'
# 28 'total_pymnt'
# 29 'total_pymnt_inv'
# 30 'total_rec_prncp'
# 31 'total_rec_int'
# 32 'total_rec_late_fee'
# 33 'recoveries'
# 34 'collection_recovery_fee'
# 35 'last_pymnt_d'
# 36 'last_pymnt_amnt'
# 37 'last_credit_pull_d'
# 38 'last_fico_range_high'
# 39 'last_fico_range_low'
# 40 'collections_12_mths_ex_med'
# 41 'mths_since_last_major_derog'
# 42 'policy_code'
# 43 'application_type'
# 44 'annual_inc_joint'
# 45 'dti_joint'
# 46 'verification_status_joint'
# 47 'acc_now_delinq'
# 48 'tot_coll_amt'
# 49 'tot_cur_bal'
# 50 'open_acc_6m'
# 51 'open_act_il'
# 52 'open_il_12m'
# 53 'open_il_24m'
# 54 'mths_since_rcnt_il'
# 55 'total_bal_il'
# 56 'il_util'
# 57 'open_rv_12m'
# 58 'open_rv_24m'
# 59 'max_bal_bc'
# 60 'all_util'
# 61 'total_rev_hi_lim'
# 62 'inq_fi'
# 63 'total_cu_tl'
# 64 'inq_last_12m'
# 65 'acc_open_past_24mths'
# 66 'avg_cur_bal'
# 67 'bc_open_to_buy'
# 68 'bc_util'
# 69 'chargeoff_within_12_mths'
# 70 'delinq_amnt'
# 71 'mo_sin_old_il_acct'
# 72 'mo_sin_old_rev_tl_op'
# 73 'mo_sin_rcnt_rev_tl_op'
# 74 'mo_sin_rcnt_tl'
# 75 'mort_acc'
# 76 'mths_since_recent_bc'
# 77 'mths_since_recent_bc_dlq'
# 78 'mths_since_recent_inq'
# 79 'mths_since_recent_revol_delinq'
# 80 'num_accts_ever_120_pd'
# 81 'num_actv_bc_tl'
# 82 'num_actv_rev_tl'
# 83 'num_bc_sats'
# 84 'num_bc_tl'
# 85 'num_il_tl'
# 86 'num_op_rev_tl'
# 87 'num_rev_accts'
# 88 'num_rev_tl_bal_gt_0'
# 89 'num_sats'
# 90 'num_tl_120dpd_2m'
# 91 'num_tl_30dpd'
# 92 'num_tl_90g_dpd_24m'
# 93 'num_tl_op_past_12m'
# 94 'pct_tl_nvr_dlq'
# 95 'percent_bc_gt_75'
# 96 'pub_rec_bankruptcies'
# 97 'tax_liens'
# 98 'tot_hi_cred_lim'
# 99 'total_bal_ex_mort'
# 100 'total_bc_limit'
# 101 'total_il_high_credit_limit'
# 102 'revol_bal_joint'
# 103 'sec_app_fico_range_low'
# 104 'sec_app_earliest_cr_line'
# 105 'sec_app_inq_last_6mths'
# 106 'sec_app_mort_acc'
# 107 'sec_app_open_acc'
# 108 'sec_app_revol_util'
# 109 'sec_app_open_act_il'
# 110 'sec_app_num_rev_accts'
# 111 'sec_app_chargeoff_within_12_mths'
# 112 'sec_app_collections_12_mths_ex_med'
# 113 'sec_app_mths_since_last_major_derog'
# 114 'disb_direct'
# 115 'debt_settlement_flag_date'
# 116 'issue_year'
# 117 'issue_month'
# 118 'fico'
# 119 'term_60'
# 120 'last_pay_d'
# 121 'months_of_pay'
# 122 'loss_amnt'
# 123 'good'
# 124 'earliest_credit_10_more'

# %% [markdown]
# What goes into FICO scores? A popular FICO score chart describes the main factors that affect score are 35% payment history,
# 30% debt owed, 15% age of credit history, 10% new credit, and 10% types of credit.
#
#
#
#
#
# https://www.econ.berkeley.edu/sites/default/files/KyleJacksonHonorsThesis.pdf

# %% [markdown]
# df.groupby(['loan_status', 'issue_year'])['funded_amnt_inv'].count().reset_index()
# df[df['funded_amnt_inv']!=df['funded_amnt']]
# df[df['loan_amnt']!=df['funded_amnt']]
